# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
print("""
My Lane: Lane 2 - Refresh / Content Opportunity Scoring

I chose this lane because websites often have thousands of pages, making it difficult to decide which pages should be reviewed first.

Using data such as impressions, CTR, content age, and traffic trends, we can prioritize pages that are most likely to benefit from a content refresh.

This helps content teams focus their efforts on pages with the highest potential impact.
""")
# Out:
# My Lane: Lane 2 - Refresh / Content Opportunity Scoring
#
# I chose this lane because websites often have thousands of pages, making it difficult to decide which pages should be reviewed first.
#
# Using data such as impressions, CTR, content age, and traffic trends, we can prioritize pages that are most likely to benefit from a content refresh.
#
# This helps content teams focus their efforts on pages with the highest potential impact.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
print("""
Decision:
Which webpages should be reviewed first for content refresh?

Unit of Analysis:
One webpage (content page).

Output:
A ranked list of pages ordered by refresh priority.

Action:
Content reviewers will update the highest-ranked pages first.

Cost of a Wrong Recommendation:
If an unimportant page is recommended, valuable review time is wasted.
If an important declining page is missed, the website may continue losing traffic.

Why Machine Learning?
Machine learning can identify useful patterns from multiple signals that are difficult to capture using simple hand-written rules.
""")
# Out:
# Decision:
# Which webpages should be reviewed first for content refresh?
#
# Unit of Analysis:
# One webpage (content page).
#
# Output:
# A ranked list of pages ordered by refresh priority.
#
# Action:
# Content reviewers will update the highest-ranked pages first.
#
# Cost of a Wrong Recommendation:
# If an unimportant page is recommended, valuable review time is wasted.
# If an important declining page is missed, the website may continue losing traffic.
#
# Why Machine Learning?
# Machine learning can identify useful patterns from multiple signals that are difficult to capture using simple hand-written rules.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))

declining = (df["trend_direction"].str.lower() == "down").sum()
print("Declining pages:", declining)

print("Average impressions (90 days):", round(df["impressions_90d"].mean(), 2))

print("""
Observation:
The dataset contains a large number of webpages.
Many pages are already showing a declining trend.
The average impressions indicate that many pages receive measurable search visibility.
These observations suggest that prioritizing pages for refresh is a useful decision-support problem.
""")
# Out:
# Total pages: 30000
# Declining pages: 16262
# Average impressions (90 days): 5200.37
#
# Observation:
# The dataset contains a large number of webpages.
# Many pages are already showing a declining trend.
# The average impressions indicate that many pages receive measurable search visibility.
# These observations suggest that prioritizing pages for refresh is a useful decision-support problem.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("""
What I can claim:

- This project identifies webpages that may deserve review based on observable search signals.
- The model supports decision-making by ranking pages for potential refresh.
- The results describe patterns observed in the available data.

What I cannot claim:

- I cannot prove that refreshing a page will increase traffic or rankings.
- I cannot predict Google's algorithm or guarantee future performance.
- The recommendations are intended to support human reviewers, not replace their judgment.
""")
# Out:
# What I can claim:
#
# - This project identifies webpages that may deserve review based on observable search signals.
# - The model supports decision-making by ranking pages for potential refresh.
# - The results describe patterns observed in the available data.
#
# What I cannot claim:
#
# - I cannot prove that refreshing a page will increase traffic or rankings.
# - I cannot predict Google's algorithm or guarantee future performance.
# - The recommendations are intended to support human reviewers, not replace their judgment.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
