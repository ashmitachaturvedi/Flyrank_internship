# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
print("""
ML Task Type: Ranking

Reason:
The goal is to rank webpages according to their priority for content refresh.
Pages ranked higher are reviewed first by the SEO team.
This is a ranking task because the order of recommendations is more important than assigning a simple class.
""")
# Out:
# ML Task Type: Ranking
#
# Reason:
# The goal is to rank webpages according to their priority for content refresh.
# Pages ranked higher are reviewed first by the SEO team.
# This is a ranking task because the order of recommendations is more important than assigning a simple class.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
print("""
Target:
The target is whether a webpage is showing a declining trend.

Proxy Label:
The dataset uses 'trend_direction'.
Pages with trend_direction = 'down' are treated as declining pages.

This is an observed outcome based on historical search performance rather than a manually created rule.
""")
# Out:
# Target:
# The target is whether a webpage is showing a declining trend.
#
# Proxy Label:
# The dataset uses 'trend_direction'.
# Pages with trend_direction = 'down' are treated as declining pages.
#
# This is an observed outcome based on historical search performance rather than a manually created rule.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
print("""
Success Metric: Precision@50

Reason:
Precision@50 measures how many of the top 50 recommended pages are actually declining.

A higher Precision@50 means the recommendations are more useful for the SEO team.
""")
# Out:
# Success Metric: Precision@50
#
# Reason:
# Precision@50 measures how many of the top 50 recommended pages are actually declining.
#
# A higher Precision@50 means the recommendations are more useful for the SEO team.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Unit of Analysis:")
print("One row represents one webpage (content page).\n")

print("Dataset shape:", df.shape)
print("Total webpages:", len(df))
print()

display(df[[
    "content_id",
    "trend_direction",
    "impressions_90d",
    "ctr",
    "avg_position"
]].head())
# Out:
# Unit of Analysis:
# One row represents one webpage (content page).
#
# Dataset shape: (30000, 44)
# Total webpages: 30000
#              content_id trend_direction  impressions_90d   ctr  avg_position
# 0  content_304f48230142            down             3803  0.76          10.6
# 1  content_a1fb4e703a9e            down            15320  0.05          20.3
# 2  content_9aa793d4d895            down            12581  0.09          36.5
# 3  content_331d6c4de07b          stable            11751  0.49           6.2
# 4  content_d99b7a2d90ca            down            19140  0.13          44.0

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
print("""
Why ML?

A fixed rule such as refreshing every old page ignores many important signals.

Machine learning can combine multiple features such as:
- impressions
- CTR
- average position
- content age

These relationships are more complex than a single if-else rule, making ML a better approach for prioritizing content refreshes.
""")
# Out:
# Why ML?
#
# A fixed rule such as refreshing every old page ignores many important signals.
#
# Machine learning can combine multiple features such as:
# - impressions
# - CTR
# - average position
# - content age
#
# These relationships are more complex than a single if-else rule, making ML a better approach for prioritizing content refreshes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
